# %%
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import numpy as np
import datetime as dt

import os
import requests
import yfinance as yf
from pathlib import Path
from dotenv import load_dotenv
from MCForecastTools import MCSimulation

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %%
#importing crypto historical data from csv
csv_path1 = Path ("project_files/BTC-USD_2017_2022.csv")
csv_path2 = Path ("project_files/ETH-USD_2017_2022.csv")
csv_path3 = Path ("project_files/XRP-USD_2017_2022.csv")



btc_historical = pd.read_csv(csv_path1, index_col="Date", infer_datetime_format=True, parse_dates=True)
eth_historical = pd.read_csv(csv_path2, index_col="Date", infer_datetime_format=True, parse_dates=True)
xrp_historical = pd.read_csv(csv_path3, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
#importing Nasdaq, S&P and historical data using yfinance API
ada = yf.Ticker("ADA-USD")
doge = yf.Ticker("DOGE-USD")
ixic = yf.Ticker("^IXIC")
gspc = yf.Ticker("^GSPC")
axjo = yf.Ticker("^AXJO")

#set the start and end
ada_historical = ada.history(interval="1d", start="2017-01-01", end= "2022-01-01")
doge_historical = doge.history(interval="1d", start="2017-01-01", end= "2022-01-01")
ixic_historical = ixic.history(interval="1d", start="2017-01-01", end= "2022-01-01")
gspc_historical = gspc.history(interval="1d", start="2017-01-01", end= "2022-01-01")
axjo_historical = axjo.history(interval="1d", start="2017-01-01", end= "2022-01-01")

# %%
#drop columns
btc_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
eth_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
xrp_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
ixic_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
gspc_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
ada_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
doge_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
axjo_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)

# %%
#calculate percentage change, drop na and rename columns

btc_daily_change = btc_historical.pct_change().dropna().rename(columns={"Close":"Bitcoin"})
eth_daily_change = eth_historical.pct_change().dropna().rename(columns={"Close":"Ethereum"})
xrp_daily_change = xrp_historical.pct_change().dropna().rename(columns={"Close":"Ripple"})
ixic_daily_change =  ixic_historical.pct_change().dropna().rename(columns={"Close":"Nasdaq"})
gspc_daily_change = gspc_historical.pct_change().dropna().rename(columns={"Close":"S&P500"})
ada_daily_change = ada_historical.pct_change().dropna().rename(columns={"Close":"Cardano"})
doge_daily_change = doge_historical.pct_change().dropna().rename(columns={"Close":"Dogecoin"})
axjo_daily_change = axjo_historical.pct_change().dropna().rename(columns={"Close":"ASX"})

# %%
#concat dataframes
crypto_df = pd.concat([btc_daily_change, eth_daily_change, xrp_daily_change, ada_daily_change, doge_daily_change], axis="columns", join="inner")
stock_df = pd.concat([ixic_daily_change, gspc_daily_change, axjo_daily_change], axis="columns", join="inner")

combined_df = pd.concat([crypto_df, stock_df], axis="columns", join="inner")

combined_df
# Out:
#              Bitcoin  Ethereum    Ripple   Cardano  Dogecoin    Nasdaq  \
# Date
# 2017-11-10 -0.073554 -0.067411 -0.050600 -0.153933 -0.178092  0.000132
# 2017-11-13  0.102422  0.028606  0.030926  0.076365  0.166667  0.000987
# 2017-11-14  0.011626  0.066037  0.031375  0.016352 -0.022296 -0.002920
# 2017-11-15  0.102444 -0.012659  0.014922  0.008197  0.130912 -0.004699
# 2017-11-16  0.076023 -0.007298  0.066450  0.042919  0.038088  0.012985
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-21  0.043864  0.021967  0.077081  0.034419  0.023028  0.024041
# 2021-12-22 -0.006296 -0.009492  0.007443  0.036836  0.011912  0.011785
# 2021-12-23  0.044337  0.031621  0.040417  0.110426  0.065099  0.008471
# 2021-12-29 -0.024042 -0.045348 -0.042494 -0.050953 -0.036481 -0.000982
# 2021-12-30  0.015791  0.023514  0.028082  0.022243  0.021149 -0.001564
#
#               S&P500       ASX
# Date
# 2017-11-10 -0.000898 -0.003306
# 2017-11-13  0.000984 -0.001261
# 2017-11-14 -0.002310 -0.009266
# 2017-11-15 -0.005526 -0.005330
# 2017-11-16  0.008196  0.001567
# ...              ...       ...
# 2021-12-21  0.017778  0.008612
# 2021-12-22  0.010180  0.001332
# 2021-12-23  0.006224  0.003096
# 2021-12-29  0.001402  0.012062
# 2021-12-30 -0.002990  0.000479
#
# [1020 rows x 8 columns]

# %%
#plot daily returns
combined_df.plot(figsize=(14, 9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#standard deviation 
combined_df.std()
# Out:
# Bitcoin     0.044738
# Ethereum    0.055312
# Ripple      0.076674
# Cardano     0.084787
# Dogecoin    0.137212
# Nasdaq      0.014755
# S&P500      0.013164
# ASX         0.011082
# dtype: float64

# %%
#plot cumulative returns

cum_returns = (1 + combined_df).cumprod() - 1

cum_returns.plot(figsize=(20,13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#calculating annualized standard deviation

annualized_btc_std= btc_daily_change.std() * np.sqrt(365)
annualized_eth_std= eth_daily_change.std() * np.sqrt(365)
annualized_xrp_std= xrp_daily_change.std() * np.sqrt(365)
annualized_ada_std= ada_daily_change.std() * np.sqrt(365)
annualized_doge_std= doge_daily_change.std() * np.sqrt(365)
annualized_ixic_std= ixic_daily_change.std() * np.sqrt(256)
annualized_gspc_std= gspc_daily_change.std() * np.sqrt(256)
annualized_axjo_std= axjo_daily_change.std() * np.sqrt(256)

print(f"The annualized standard deviation for Bitcoin is : {annualized_btc_std.values}")
print(f"The annualized standard deviation for Ethereum is : {annualized_eth_std.values}")
print(f"The annualized standard deviation for Ripple is : {annualized_xrp_std.values}")
print(f"The annualized standard deviation for Cardano is : {annualized_ada_std.values}")
print(f"The annualized standard deviation for Dogecoin is : {annualized_doge_std.values}")
print(f"The annualized standard deviation for S&P500 is : {annualized_gspc_std.values}")
print(f"The annualized standard deviation for Nasdaq is : {annualized_ixic_std.values}")
print(f"The annualized standard deviation for ASX is : {annualized_axjo_std.values}")
# Out:
# The annualized standard deviation for Bitcoin is : [0.80157159]
# The annualized standard deviation for Ethereum is : [0.98978657]
# The annualized standard deviation for Ripple is : [1.35829544]
# The annualized standard deviation for Cardano is : [1.52254528]
# The annualized standard deviation for Dogecoin is : [2.31070692]
# The annualized standard deviation for S&P500 is : [0.1939719]
# The annualized standard deviation for Nasdaq is : [0.21911942]
# The annualized standard deviation for ASX is : [0.16489468]

# %%
#calculating rolling standard deviation of the combined porfolio
combined_df.rolling(window =21).std().plot(figsize=(20, 13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#correlation
correlation = combined_df.corr()
correlation.style.background_gradient(cmap="winter")
# Out:
# <style type="text/css">
# #T_fbae9_row0_col0, #T_fbae9_row1_col1, #T_fbae9_row2_col2, #T_fbae9_row3_col3, #T_fbae9_row4_col4, #T_fbae9_row5_col5, #T_fbae9_row6_col6, #T_fbae9_row7_col7 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_fbae9_row0_col1, #T_fbae9_row1_col0 {
#   background-color: #00bfa0;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col2 {
#   background-color: #007ac2;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col3 {
#   background-color: #007bc2;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col4 {
#   background-color: #0055d4;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col5 {
#   background-color: #002de8;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col6 {
#   background-color: #0025ec;
#   color: #f1f1f1;
# }
# #T_fbae9_row0_col7 {
#   background-color: #001ef0;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col2, #T_fbae9_row2_col3 {
#   background-color: #009ab2;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col3 {
#   background-color: #008fb8;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col4 {
#   background-color: #0050d7;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col5 {
#   background-color: #0031e6;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col6 {
#   background-color: #002bea;
#   color: #f1f1f1;
# }
# #T_fbae9_row1_col7, #T_fbae9_row5_col3, #T_fbae9_row6_col3 {
#   background-color: #0020ef;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col0 {
#   background-color: #0071c6;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col1 {
#   background-color: #0092b6;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col4, #T_fbae9_row3_col4 {
#   background-color: #0046dc;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col5, #T_fbae9_row3_col7 {
#   background-color: #0014f5;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col6 {
#   background-color: #0010f7;
#   color: #f1f1f1;
# }
# #T_fbae9_row2_col7 {
#   background-color: #000ef8;
#   color: #f1f1f1;
# }
# #T_fbae9_row3_col0 {
#   background-color: #0075c4;
#   color: #f1f1f1;
# }
# #T_fbae9_row3_col1 {
#   background-color: #0089bb;
#   color: #f1f1f1;
# }
# #T_fbae9_row3_col2 {
#   background-color: #009cb1;
#   color: #f1f1f1;
# }
# #T_fbae9_row3_col5, #T_fbae9_row6_col4 {
#   background-color: #001bf2;
#   color: #f1f1f1;
# }
# #T_fbae9_row3_col6, #T_fbae9_row5_col4 {
#   background-color: #0019f2;
#   color: #f1f1f1;
# }
# #T_fbae9_row4_col0 {
#   background-color: #003ee0;
#   color: #f1f1f1;
# }
# #T_fbae9_row4_col1, #T_fbae9_row4_col3 {
#   background-color: #0036e4;
#   color: #f1f1f1;
# }
# #T_fbae9_row4_col2 {
#   background-color: #003be2;
#   color: #f1f1f1;
# }
# #T_fbae9_row4_col5, #T_fbae9_row4_col6, #T_fbae9_row4_col7, #T_fbae9_row7_col0, #T_fbae9_row7_col1, #T_fbae9_row7_col2, #T_fbae9_row7_col3, #T_fbae9_row7_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_fbae9_row5_col0 {
#   background-color: #0028eb;
#   color: #f1f1f1;
# }
# #T_fbae9_row5_col1 {
#   background-color: #002aea;
#   color: #f1f1f1;
# }
# #T_fbae9_row5_col2 {
#   background-color: #001ff0;
#   color: #f1f1f1;
# }
# #T_fbae9_row5_col6, #T_fbae9_row6_col5 {
#   background-color: #00f087;
#   color: #000000;
# }
# #T_fbae9_row5_col7, #T_fbae9_row7_col6 {
#   background-color: #005ed0;
#   color: #f1f1f1;
# }
# #T_fbae9_row6_col0 {
#   background-color: #0023ee;
#   color: #f1f1f1;
# }
# #T_fbae9_row6_col1 {
#   background-color: #0026ec;
#   color: #f1f1f1;
# }
# #T_fbae9_row6_col2 {
#   background-color: #001df0;
#   color: #f1f1f1;
# }
# #T_fbae9_row6_col7 {
#   background-color: #0070c7;
#   color: #f1f1f1;
# }
# #T_fbae9_row7_col5 {
#   background-color: #004cd9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fbae9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Bitcoin</th>
#       <th class="col_heading level0 col1" >Ethereum</th>
#       <th class="col_heading level0 col2" >Ripple</th>
#       <th class="col_heading level0 col3" >Cardano</th>
#       <th class="col_heading level0 col4" >Dogecoin</th>
#       <th class="col_heading level0 col5" >Nasdaq</th>
#       <th class="col_heading level0 col6" >S&P500</th>
#       <th class="col_heading level0 col7" >ASX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbae9_level0_row0" class="row_heading level0 row0" >Bitcoin</th>
#       <td id="T_fbae9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fbae9_row0_col1" class="data row0 col1" >0.776456</td>
#       <td id="T_fbae9_row0_col2" class="data row0 col2" >0.503753</td>
#       <td id="T_fbae9_row0_col3" class="data row0 col3" >0.518149</td>
#       <td id="T_fbae9_row0_col4" class="data row0 col4" >0.328842</td>
#       <td id="T_fbae9_row0_col5" class="data row0 col5" >0.251640</td>
#       <td id="T_fbae9_row0_col6" class="data row0 col6" >0.231805</td>
#       <td id="T_fbae9_row0_col7" class="data row0 col7" >0.109903</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row1" class="row_heading level0 row1" >Ethereum</th>
#       <td id="T_fbae9_row1_col0" class="data row1 col0" >0.776456</td>
#       <td id="T_fbae9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fbae9_row1_col2" class="data row1 col2" >0.624061</td>
#       <td id="T_fbae9_row1_col3" class="data row1 col3" >0.590383</td>
#       <td id="T_fbae9_row1_col4" class="data row1 col4" >0.306745</td>
#       <td id="T_fbae9_row1_col5" class="data row1 col5" >0.266006</td>
#       <td id="T_fbae9_row1_col6" class="data row1 col6" >0.250140</td>
#       <td id="T_fbae9_row1_col7" class="data row1 col7" >0.118299</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row2" class="row_heading level0 row2" >Ripple</th>
#       <td id="T_fbae9_row2_col0" class="data row2 col0" >0.503753</td>
#       <td id="T_fbae9_row2_col1" class="data row2 col1" >0.624061</td>
#       <td id="T_fbae9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fbae9_row2_col3" class="data row2 col3" >0.630403</td>
#       <td id="T_fbae9_row2_col4" class="data row2 col4" >0.268189</td>
#       <td id="T_fbae9_row2_col5" class="data row2 col5" >0.163339</td>
#       <td id="T_fbae9_row2_col6" class="data row2 col6" >0.155803</td>
#       <td id="T_fbae9_row2_col7" class="data row2 col7" >0.047760</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row3" class="row_heading level0 row3" >Cardano</th>
#       <td id="T_fbae9_row3_col0" class="data row3 col0" >0.518149</td>
#       <td id="T_fbae9_row3_col1" class="data row3 col1" >0.590383</td>
#       <td id="T_fbae9_row3_col2" class="data row3 col2" >0.630403</td>
#       <td id="T_fbae9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fbae9_row3_col4" class="data row3 col4" >0.268348</td>
#       <td id="T_fbae9_row3_col5" class="data row3 col5" >0.188999</td>
#       <td id="T_fbae9_row3_col6" class="data row3 col6" >0.187676</td>
#       <td id="T_fbae9_row3_col7" class="data row3 col7" >0.069444</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row4" class="row_heading level0 row4" >Dogecoin</th>
#       <td id="T_fbae9_row4_col0" class="data row4 col0" >0.328842</td>
#       <td id="T_fbae9_row4_col1" class="data row4 col1" >0.306745</td>
#       <td id="T_fbae9_row4_col2" class="data row4 col2" >0.268189</td>
#       <td id="T_fbae9_row4_col3" class="data row4 col3" >0.268348</td>
#       <td id="T_fbae9_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_fbae9_row4_col5" class="data row4 col5" >0.091293</td>
#       <td id="T_fbae9_row4_col6" class="data row4 col6" >0.098273</td>
#       <td id="T_fbae9_row4_col7" class="data row4 col7" >-0.010091</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row5" class="row_heading level0 row5" >Nasdaq</th>
#       <td id="T_fbae9_row5_col0" class="data row5 col0" >0.251640</td>
#       <td id="T_fbae9_row5_col1" class="data row5 col1" >0.266006</td>
#       <td id="T_fbae9_row5_col2" class="data row5 col2" >0.163339</td>
#       <td id="T_fbae9_row5_col3" class="data row5 col3" >0.188999</td>
#       <td id="T_fbae9_row5_col4" class="data row5 col4" >0.091293</td>
#       <td id="T_fbae9_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_fbae9_row5_col6" class="data row5 col6" >0.945029</td>
#       <td id="T_fbae9_row5_col7" class="data row5 col7" >0.361572</td>
#     </tr>
#     <tr>
#       <th id="T_fbae9_level0_row6" class="row_heading level0 row6" >S&P500</th>
#       <td id="T_fbae9_row6_col0" class="data row6 col0" >0.231805</td>
#       <td

# %%
#sharpe ratios
sharpe_ratio_stocks = (stock_df.mean() *252) / (stock_df.std() * np.sqrt(252))
sharpe_ratio_crypto = (crypto_df.mean() *365) / (crypto_df.std() * np.sqrt(365))

# %%
stock_pl = px.bar(sharpe_ratio_stocks, title="Stock Market Sharpe Ratios")
crypto_pl =px.bar(sharpe_ratio_crypto, title="Crypto Market Sharpe Ratios" )

# %%
tabs = pn.Tabs(
    ("Stock", stock_pl),
    ("Crypto", crypto_pl)
    
    
    
)
tabs
# Out:
# Tabs
#     [0] Plotly(Figure, name='Stock')
#     [1] Plotly(Figure, name='Crypto')
