# %%
import pandas as pd
import numpy as np
import datetime as dt

import os
import requests
import alpaca_trade_api as tradeapi
import yfinance as yf
from pathlib import Path
from dotenv import load_dotenv
from coinpaprika import client as Coinpaprika
from MCForecastTools import MCSimulation

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Create the Alpaca API object
api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version = "v2"
)

# %%
#importing crypto historical data from csv
csv_path1 = Path ("project_files/BTC-USD_2017_2022.csv")
csv_path2 = Path ("project_files/ETH-USD_2017_2022.csv")
csv_path3 = Path ("project_files/XRP-USD_2017_2022.csv")



btc_historical = pd.read_csv(csv_path1, index_col="Date", infer_datetime_format=True, parse_dates=True)
eth_historical = pd.read_csv(csv_path2, index_col="Date", infer_datetime_format=True, parse_dates=True)
xrp_historical = pd.read_csv(csv_path3, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
#importing Nasdaq, S&P and historical data using yfinance API
ixic = yf.Ticker("^IXIC")
gspc = yf.Ticker("^GSPC")
ada = yf.Ticker("ADA-USD")
ixic_historical = ixic.history(interval="1d", start="2017-01-01", end= "2022-01-01")
gspc_historical = gspc.history(interval="1d", start="2017-01-01", end= "2022-01-01")
ada_historical = ada.history(interval="1d", start="2017-01-01", end= "2022-01-01")

# %%
#drop columns
btc_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
eth_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
xrp_historical.drop(['High',"Low", "Open", "Adj Close", "Volume"], axis=1, inplace=True)
ixic_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
gspc_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)
ada_historical.drop(['High',"Low", "Open", "Stock Splits", "Volume", "Dividends"], axis=1, inplace=True)

# %%
#calculate percentage change and drop nulls

btc_daily_change = btc_historical.pct_change().dropna()
eth_daily_change = eth_historical.pct_change().dropna()
xrp_daily_change = xrp_historical.pct_change().dropna()
ixic_daily_change =  ixic_historical.pct_change().dropna()
gspc_daily_change = gspc_historical.pct_change().dropna()
ada_daily_change = ada_historical.pct_change().dropna()

# %%
#rename columns
btc_daily_change = btc_daily_change.rename(columns={"Close":"BTC Close"})
eth_daily_change = eth_daily_change.rename(columns={"Close":"ETH Close"})
xrp_daily_change = xrp_daily_change.rename(columns={"Close":"XRP Close"})
ixic_daily_change = ixic_daily_change.rename(columns={"Close":"IXIC Close"})
gspc_daily_change = gspc_daily_change.rename(columns={"Close":"GSPC Close"})
ada_daily_change = ada_daily_change.rename(columns={"Close":"ADA Close"})

# %%
#concat the dataframes
combined_df = pd.concat([btc_daily_change, eth_daily_change, xrp_daily_change, ada_daily_change, ixic_daily_change, gspc_daily_change], axis="columns", join="inner")

combined_df
# Out:
#             BTC Close  ETH Close  XRP Close  ADA Close  IXIC Close  GSPC Close
# Date
# 2017-11-10  -0.073554  -0.067411  -0.050600  -0.153933    0.000132   -0.000898
# 2017-11-13   0.102422   0.028606   0.030926   0.076365    0.000987    0.000984
# 2017-11-14   0.011626   0.066037   0.031375   0.016352   -0.002920   -0.002310
# 2017-11-15   0.102444  -0.012659   0.014922   0.008197   -0.004699   -0.005526
# 2017-11-16   0.076023  -0.007298   0.066450   0.042919    0.012985    0.008196
# ...               ...        ...        ...        ...         ...         ...
# 2021-12-23   0.044337   0.031621   0.040417   0.110426    0.008471    0.006224
# 2021-12-27  -0.003328  -0.007322   0.005432   0.039056    0.013920    0.013839
# 2021-12-28  -0.060259  -0.058613  -0.079060  -0.073136   -0.005642   -0.001010
# 2021-12-29  -0.024042  -0.045348  -0.042494  -0.050953   -0.000982    0.001402
# 2021-12-30   0.015791   0.023514   0.028082   0.022243   -0.001564   -0.002990
#
# [1041 rows x 6 columns]

# %%
#plot daily returns
combined_df.plot(figsize=(14, 9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#standard deviation 
combined_df.std()
# Out:
# BTC Close     0.044752
# ETH Close     0.055121
# XRP Close     0.077388
# ADA Close     0.084324
# IXIC Close    0.014792
# GSPC Close    0.013184
# dtype: float64

# %%
#plot cumulative returns

cum_returns = (1 + combined_df).cumprod() - 1

cum_returns.plot(figsize=(20,13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#calculate annualized standard deviation

annualized_btc_std= btc_daily_change.std() * np.sqrt(365)
annualized_eth_std= eth_daily_change.std() * np.sqrt(365)
annualized_xrp_std= xrp_daily_change.std() * np.sqrt(365)
annualized_ada_std= ada_daily_change.std() * np.sqrt(365)
annualized_ixic_std= ixic_daily_change.std() * np.sqrt(256)
annualized_gspc_std= gspc_daily_change.std() * np.sqrt(256)
print(f"The annualized standard deviation for btc is : {annualized_btc_std.values}")
print(f"The annualized standard deviation for eth is : {annualized_eth_std.values}")
print(f"The annualized standard deviation for xrp is : {annualized_xrp_std.values}")
print(f"The annualized standard deviation for ada is : {annualized_ada_std.values}")
print(f"The annualized standard deviation for gspc is : {annualized_gspc_std.values}")
print(f"The annualized standard deviation for ixic is : {annualized_ixic_std.values}")
# Out:
# The annualized standard deviation for btc is : [0.80157159]
# The annualized standard deviation for eth is : [0.98978657]
# The annualized standard deviation for xrp is : [1.35829544]
# The annualized standard deviation for ada is : [1.52254528]
# The annualized standard deviation for gspc is : [0.1939719]
# The annualized standard deviation for ixic is : [0.21911942]

# %%
#calculate rolling standard deviation

# %%
#calculate rolling standard deviation of the combined porfolio
combined_df.rolling(window =21).std().plot(figsize=(20, 13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#correlation
correlation = combined_df.corr()
correlation.style.background_gradient(cmap="winter")
# Out:
# <style type="text/css">
# #T_e6848_row0_col0, #T_e6848_row1_col1, #T_e6848_row2_col2, #T_e6848_row3_col3, #T_e6848_row4_col4, #T_e6848_row5_col5 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_e6848_row0_col1 {
#   background-color: #00b3a6;
#   color: #f1f1f1;
# }
# #T_e6848_row0_col2 {
#   background-color: #0068cb;
#   color: #f1f1f1;
# }
# #T_e6848_row0_col3 {
#   background-color: #0069cb;
#   color: #f1f1f1;
# }
# #T_e6848_row0_col4 {
#   background-color: #0019f2;
#   color: #f1f1f1;
# }
# #T_e6848_row0_col5 {
#   background-color: #0015f4;
#   color: #f1f1f1;
# }
# #T_e6848_row1_col0 {
#   background-color: #00b5a4;
#   color: #f1f1f1;
# }
# #T_e6848_row1_col2 {
#   background-color: #008bba;
#   color: #f1f1f1;
# }
# #T_e6848_row1_col3 {
#   background-color: #0080bf;
#   color: #f1f1f1;
# }
# #T_e6848_row1_col4 {
#   background-color: #001ef0;
#   color: #f1f1f1;
# }
# #T_e6848_row1_col5 {
#   background-color: #001cf1;
#   color: #f1f1f1;
# }
# #T_e6848_row2_col0 {
#   background-color: #0059d2;
#   color: #f1f1f1;
# }
# #T_e6848_row2_col1 {
#   background-color: #007cc1;
#   color: #f1f1f1;
# }
# #T_e6848_row2_col3 {
#   background-color: #0088bb;
#   color: #f1f1f1;
# }
# #T_e6848_row2_col4, #T_e6848_row2_col5, #T_e6848_row4_col3, #T_e6848_row5_col0, #T_e6848_row5_col1, #T_e6848_row5_col2, #T_e6848_row5_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_e6848_row3_col0 {
#   background-color: #0061ce;
#   color: #f1f1f1;
# }
# #T_e6848_row3_col1 {
#   background-color: #0075c4;
#   color: #f1f1f1;
# }
# #T_e6848_row3_col2 {
#   background-color: #008cb9;
#   color: #f1f1f1;
# }
# #T_e6848_row3_col4 {
#   background-color: #0007fc;
#   color: #f1f1f1;
# }
# #T_e6848_row3_col5 {
#   background-color: #0009fa;
#   color: #f1f1f1;
# }
# #T_e6848_row4_col0 {
#   background-color: #0006fc;
#   color: #f1f1f1;
# }
# #T_e6848_row4_col1 {
#   background-color: #0005fc;
#   color: #f1f1f1;
# }
# #T_e6848_row4_col2 {
#   background-color: #0002fe;
#   color: #f1f1f1;
# }
# #T_e6848_row4_col5, #T_e6848_row5_col4 {
#   background-color: #00ef88;
#   color: #000000;
# }
# </style>
# <table id="T_e6848_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BTC Close</th>
#       <th class="col_heading level0 col1" >ETH Close</th>
#       <th class="col_heading level0 col2" >XRP Close</th>
#       <th class="col_heading level0 col3" >ADA Close</th>
#       <th class="col_heading level0 col4" >IXIC Close</th>
#       <th class="col_heading level0 col5" >GSPC Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6848_level0_row0" class="row_heading level0 row0" >BTC Close</th>
#       <td id="T_e6848_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e6848_row0_col1" class="data row0 col1" >0.774861</td>
#       <td id="T_e6848_row0_col2" class="data row0 col2" >0.497793</td>
#       <td id="T_e6848_row0_col3" class="data row0 col3" >0.519924</td>
#       <td id="T_e6848_row0_col4" class="data row0 col4" >0.245001</td>
#       <td id="T_e6848_row0_col5" class="data row0 col5" >0.225893</td>
#     </tr>
#     <tr>
#       <th id="T_e6848_level0_row1" class="row_heading level0 row1" >ETH Close</th>
#       <td id="T_e6848_row1_col0" class="data row1 col0" >0.774861</td>
#       <td id="T_e6848_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e6848_row1_col2" class="data row1 col2" >0.614412</td>
#       <td id="T_e6848_row1_col3" class="data row1 col3" >0.593579</td>
#       <td id="T_e6848_row1_col4" class="data row1 col4" >0.262954</td>
#       <td id="T_e6848_row1_col5" class="data row1 col5" >0.247388</td>
#     </tr>
#     <tr>
#       <th id="T_e6848_level0_row2" class="row_heading level0 row2" >XRP Close</th>
#       <td id="T_e6848_row2_col0" class="data row2 col0" >0.497793</td>
#       <td id="T_e6848_row2_col1" class="data row2 col1" >0.614412</td>
#       <td id="T_e6848_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e6848_row2_col3" class="data row2 col3" >0.619538</td>
#       <td id="T_e6848_row2_col4" class="data row2 col4" >0.162031</td>
#       <td id="T_e6848_row2_col5" class="data row2 col5" >0.154079</td>
#     </tr>
#     <tr>
#       <th id="T_e6848_level0_row3" class="row_heading level0 row3" >ADA Close</th>
#       <td id="T_e6848_row3_col0" class="data row3 col0" >0.519924</td>
#       <td id="T_e6848_row3_col1" class="data row3 col1" >0.593579</td>
#       <td id="T_e6848_row3_col2" class="data row3 col2" >0.619538</td>
#       <td id="T_e6848_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e6848_row3_col4" class="data row3 col4" >0.185721</td>
#       <td id="T_e6848_row3_col5" class="data row3 col5" >0.184516</td>
#     </tr>
#     <tr>
#       <th id="T_e6848_level0_row4" class="row_heading level0 row4" >IXIC Close</th>
#       <td id="T_e6848_row4_col0" class="data row4 col0" >0.245001</td>
#       <td id="T_e6848_row4_col1" class="data row4 col1" >0.262954</td>
#       <td id="T_e6848_row4_col2" class="data row4 col2" >0.162031</td>
#       <td id="T_e6848_row4_col3" class="data row4 col3" >0.185721</td>
#       <td id="T_e6848_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e6848_row4_col5" class="data row4 col5" >0.945489</td>
#     </tr>
#     <tr>
#       <th id="T_e6848_level0_row5" class="row_heading level0 row5" >GSPC Close</th>
#       <td id="T_e6848_row5_col0" class="data row5 col0" >0.225893</td>
#       <td id="T_e6848_row5_col1" class="data row5 col1" >0.247388</td>
#       <td id="T_e6848_row5_col2" class="data row5 col2" >0.154079</td>
#       <td id="T_e6848_row5_col3" class="data row5 col3" >0.184516</td>
#       <td id="T_e6848_row5_col4" class="data row5 col4" >0.945489</td>
#       <td id="T_e6848_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
MC_even_dist = MCSimulation(
    portfolio_data = combined_df,
    weights = [1],
    num_simulation = 500,
    num_trading_days = 365*10
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11452/4283511420.py in <module>
#       3     weights = [1],
#       4     num_simulation = 500,
# ----> 5     num_trading_days = 365*10
#       6 )
#
# ~\Git\coinpaprika-api-python-client-master\examples\MCForecastTools.py in __init__(self, portfolio_data, weights, num_simulation, num_trading_days)
#      59
#      60         # Calculate daily return if not within dataframe
# ---> 61         if not "daily_return" in portfolio_data.columns.get_level_values(1).unique():
#      62             close_df = portfolio_data.xs('close',level=1,axis=1).pct_change()
#      63             tickers = portfolio_data.columns.get_level_values(0).unique()
#
# ~\Anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    1805         Index(['a', 'b', 'c'], dtype='object')
#    1806         """
# -> 1807         self._validate_index_level(level)
#    1808         return self
#    1809
#
# ~\Anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1725             elif level > 0:
#    1726                 raise IndexError(
# -> 1727                     f"Too many levels: Index has only 1 level, not {level + 1}"
#    1728                 )
#    1729         elif level != self.name:
#
# IndexError: Too many levels: Index has only 1 level, not 2

# %%
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-01-03   5425.620117   5452.569824   5397.990234   5429.080078
# 2017-01-04   5440.910156   5482.350098   5440.240234   5477.000000
# 2017-01-05   5474.390137   5495.850098   5464.359863   5487.939941
# 2017-01-06   5499.080078   5536.520020   5482.810059   5521.060059
# 2017-01-09   5527.580078   5541.080078   5517.140137   5531.819824
# ...                  ...           ...           ...           ...
# 2021-12-23  15544.790039  15697.980469  15528.910156  15653.370117
# 2021-12-27  15696.830078  15871.400391  15696.830078  15871.259766
# 2021-12-28  15895.200195  15901.469727  15757.070312  15781.719727
# 2021-12-29  15794.919922  15821.809570  15679.849609  15766.219727
# 2021-12-30  15758.980469  15868.089844  15729.160156  15741.559570
#
#                 Volume  Dividends  Stock Splits
# Date
# 2017-01-03  1886200000          0             0
# 2017-01-04  1883360000          0             0
# 2017-01-05  1792610000          0             0
# 2017-01-06  1710770000          0             0
# 2017-01-09  1885500000          0             0
# ...                ...        ...           ...
# 2021-12-23  3918200000          0             0
# 2021-12-27  3730120000          0             0
# 2021-12-28  3623600000          0             0
# 2021-12-29  3694500000          0             0
# 2021-12-30  3732730000          0             0
#
# [1258 rows x 7 columns]
